# %%
import numpy as np
import imageio
import matplotlib.pyplot as plt
import cv2

# %%
#load gambar menggunakan open cv
img =cv2.imread("toot.jpg")
img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)

# %%
#menentukan resolusi dan type dari gambar
img_height = img.shape[0]
img_width = img.shape[1]
img_channel = img.shape[2]
img_type = img.dtype

# %%
#fungsi membalik gambar menjadi horizontal
for y in range(0, img_height):
    for x in range(0, img_width):
        for c in range(0, img_channel):
            img_flip_horizontal[y][x][c] = img[y][img_width-1-x][c]

# %%
#fungsi membalik gambar secara vertikal
for y in range(0, img_height):
    for x in range(0, img_width):
        for c in range(0, img_channel):
            img_flip_vertical[y][x][c] = img[img_height-1-y][x][c]

# %%
#menampilkan hasil gambar menggunakan plot
fig = plt.figure(figsize= (4,4))
plt.imshow(img_flip_horizontal)
plt.title("Flip Horizontal")
plt.show()
fig = plt.figure(figsize= (4,4))
plt.imshow(img_flip_vertical)
plt.title("Flip Vertical")
plt.show()
